# %%
import sys
sys.path.append("..")
from utils.telegram_bot import TelegramBot

bot = TelegramBot(chat_id="1731149425")
await bot.send("Hello from Jupyter async 002 ✅")
# Out:
# ✅ Sent to Telegram: Hello from Jupyter async 002 ✅
